# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # dataset upload

# %%
df1=pd.read_csv(r'bitcoin.csv')
df1
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2708  2022-02-15  42586.464844  44667.218750  42491.035156  44575.203125
# 2709  2022-02-16  44578.277344  44578.277344  43456.691406  43961.859375
# 2710  2022-02-17  43937.070313  44132.972656  40249.371094  40538.011719
# 2711  2022-02-18  40552.132813  40929.152344  39637.617188  40030.976563
# 2712  2022-02-19  40022.132813  40246.027344  40010.867188  40126.429688
#
#          Adj Close       Volume
# 0       457.334015     21056800
# ...

# %%
df=df1.copy()

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
#
#      Volume
# 0  21056800
# 1  34483200
# 2  37919700
# 3  36863600
# 4  26580100

# %%
df.dropna(inplace=True)

df['Date'] = pd.to_datetime(df['Date'])
df.sort_values('Date', inplace=True)

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#                                 Date          Open          High  \
# count                           2713   2713.000000   2713.000000
# mean   2018-06-04 00:00:00.000000256  11311.041069  11614.292482
# min              2014-09-17 00:00:00    176.897003    211.731003
# 25%              2016-07-26 00:00:00    606.396973    609.260986
# 50%              2018-06-04 00:00:00   6301.569824   6434.617676
# 75%              2020-04-12 00:00:00  10452.399414  10762.644531
# max              2022-02-19 00:00:00  67549.734375  68789.625000
# std                              NaN  16106.428891  16537.390649
#
#                 Low         Close     Adj Close        Volume
# count   2713.000000   2713.000000   2713.000000  2.713000e+03
# mean   10975.555057  11323.914637  11323.914637  1.470462e+10
# min      171.509995    178.102997    178.102997  5.914570e+06
# 25%      604.109985    606.718994    606.718994  7.991080e+07
# 50%     6214.220215   6317.609863   6317.609863  5.098183e+09
# ...

# %%
df.shape
# Out:
# (2713, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2713 entries, 0 to 2712
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2713 non-null   datetime64[ns]
#  1   Open       2713 non-null   float64
#  2   High       2713 non-null   float64
#  3   Low        2713 non-null   float64
#  4   Close      2713 non-null   float64
#  5   Adj Close  2713 non-null   float64
#  6   Volume     2713 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 148.5 KB

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Close'])
plt.title('Bitcoin Prise Detection',fontsize=15)
plt.ylabel('Price in dollars.')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[df['Close'] == df['Adj Close']].shape, df.shape
# Out:
# ((2713, 7), (2713, 7))

# %%
df = df.drop(['Adj Close'], axis=1)

# %%
plt.figure(figsize=(8, 5))
sns.distplot(df['Open'])
plt.title('Distribution of Open')
plt.show()
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_25824\633348093.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Open'])

# %%
plt.figure(figsize=(8, 5))
sns.distplot(df['High'])
plt.title('Distribution of High')
plt.show()
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_25824\1943618654.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['High'])

# %%
plt.figure(figsize=(8, 5))
sns.distplot(df['Low'])
plt.title('Distribution of Low')
plt.show()
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_25824\3189891106.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Low'])

# %%
plt.figure(figsize=(8, 5))
sns.distplot(df['Close'])
plt.title('Distribution of Close')
plt.show()
# Out:
# C:\Users\ishwa\AppData\Local\Temp\ipykernel_25824\1072127448.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Close'])

# %%
features = ['Open', 'High', 'Low', 'Close']

plt.figure(figsize=(20, 10))

for i, col in enumerate(features):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df[col], orient='h')
    plt.title(col)

plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])  # safe even if already datetime

df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month
df['day'] = df['Date'].dt.day

df.head()
# Out:
#         Date        Open        High         Low       Close    Volume  year  \
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800  2014
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200  2014
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700  2014
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600  2014
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100  2014
#
#    month  day
# 0      9   17
# 1      9   18
# 2      9   19
# 3      9   20
# 4      9   21

# %%
data_grouped = df.groupby('year').mean()
plt.subplots(figsize=(20,10))
for i, col in enumerate(['Open', 'High', 'Low', 'Close']):
  plt.subplot(2,2,i+1)
  data_grouped[col].plot.bar()
plt.show()

# %%
df['open-close']  = df['Open'] - df['Close']
df['low-high']  = df['Low'] - df['High']
df['is_quarter_end'] = np.where(df['Date'].dt.month % 3 == 0, 1, 0)
df['prev_close'] = df['Close'].shift(1)
df['price_change'] = df['Close'] - df['prev_close']
df['target'] = (df['Close'].shift(-1) > df['Close']).astype(int)
df.dropna(inplace=True)
df
# Out:
#            Date          Open          High           Low         Close  \
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# 5    2014-09-22    399.100006    406.915985    397.130005    402.152008
# ...         ...           ...           ...           ...           ...
# 2708 2022-02-15  42586.464844  44667.218750  42491.035156  44575.203125
# 2709 2022-02-16  44578.277344  44578.277344  43456.691406  43961.859375
# 2710 2022-02-17  43937.070313  44132.972656  40249.371094  40538.011719
# 2711 2022-02-18  40552.132813  40929.152344  39637.617188  40030.976563
# 2712 2022-02-19  40022.132813  40246.027344  40010.867188  40126.429688
#
#            Volume  year  month  day   open-close     low-high  is_quarter_end  \
# ...

# %%
plt.pie(df['target'].value_counts().values, 
    labels=[0, 1], autopct='%1.1f%%')
plt.show()

# %%
from sklearn.model_selection import train_test_split

X = df[['open-close', 'low-high', 'is_quarter_end','price_change']]
y = df['target']



X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    shuffle=False
)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
data=pd.concat([X,y],axis=1)
data
# Out:
#        open-close     low-high  is_quarter_end  price_change  target
# 1       32.419983   -43.755981               1    -32.894013       0
# 2       29.307007   -43.302978               1    -29.644012       1
# 3      -14.230988   -33.412994               1     14.108002       0
# 4        9.263977   -19.244995               1    -10.082978       1
# 5       -3.052002    -9.785980               1      3.330994       1
# ...           ...          ...             ...           ...     ...
# 2708 -1988.738281 -2176.183594               0   1988.285156       0
# 2709   616.417969 -1121.585938               0   -613.343750       0
# 2710  3399.058594 -3883.601562               0  -3423.847656       0
# 2711   521.156250 -1291.535156               0   -507.035156       1
# 2712  -104.296875  -235.160156               0     95.453125       0
#
# [2712 rows x 5 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier(
    n_estimators=300,
    max_depth=12,
    random_state=42
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=12, n_estimators=300, random_state=42)

# %%
y_pred=rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.47174447174447176
# Confusion Matrix:
#  [[142 241]
#  [189 242]]

# %%
data.iloc[-1]
# Out:
# open-close       -104.296875
# low-high         -235.160156
# is_quarter_end      0.000000
# price_change       95.453125
# target              0.000000
# Name: 2712, dtype: float64

# %%
cus_input=np.array([[-104.29,-235.16,0,95.45]])

# %%
result=rf.predict(cus_input)
print(result)
# Out:
# [0]

# %%
prediction=int(round(result[0]))
prediction
# Out:
# 0

# %%
def predict():
    a = float(input("Enter open-close: "))
    b = float(input("Enter low-high: "))
    c = float(input("Enter quarter end (1 or 0): "))
    d = float(input("Enter price change: "))

    cus_input = np.array([[a, b, c, d]])
    cus_input = scaler.transform(cus_input)
    result = rf.predict(cus_input)

    if result[0] == 1:
        return " Bitcoin price will go UP"
    else:
        return " Bitcoin price will go DOWN"

# %%
predict()
# Out:
# c:\Users\ishwa\OneDrive\Desktop\Python\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ' Bitcoin price will go UP'

# %%
import joblib

# %%
joblib.dump(rf,'bitcoinprice.pkl')
# Out:
# ['bitcoinprice.pkl']
